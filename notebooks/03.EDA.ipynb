# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import sys
sys.path.append('../')

from src.soporte import analisis_rapido, eda, matriz_correlacion

# %%
data = pd.read_csv('../data/output/autorenew_limpio.csv')

# %%
data.head()
# Out:
#                              name  price vehicleType  yearOfRegistration  \
# 0                      Golf_3_1.6    480     unknown                1993
# 1            A5_Sportback_2.7_Tdi  18300       coupe                2011
# 2  Jeep_Grand_Cherokee_"Overland"   9800         suv                2004
# 3              GOLF_4_1_4__3TÜRER   1500   small car                2001
# 4  Skoda_Fabia_1.4_TDI_PD_Classic   3600   small car                2008
#
#      gearbox  powerCV  kilometer fuelType       brand notRepairedDamage
# 0   manually      NaN     150000   petrol  volkswagen           unknown
# 1   manually    187.0     125000   diesel        audi               yes
# 2  automatic    161.0     125000   diesel        jeep           unknown
# 3   manually     74.0     150000   petrol  volkswagen                no
# 4   manually     68.0      90000   diesel       skoda                no

# %% [markdown]
# ### Objetivo del análisis
#
# - Averiguar qué marcas son las más vendidas, el rango de precios correspondiente y la anigüedadd de los vehículos.
# - Para evitar que vehículos que tengan daños puedan sesgar el conjunnto de datos y las conclusiones que saquemos, nos centraremos en el subconjunto de datos de vehículos sin daños.

# %%
data['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# no         258639
# unknown     64431
# yes         33235
# Name: count, dtype: int64

# %%
df= data[data['notRepairedDamage'] == 'no'].copy()

# %%
df.drop(columns=['notRepairedDamage'], inplace=True)

# %% [markdown]
# ## Análisis

# %%
analisis_rapido(df)
# Out:
# Las 5 primeras columnas son:
#                               name  price  vehicleType  yearOfRegistration  \
# 3               GOLF_4_1_4__3TÜRER   1500    small car                2001
# 4   Skoda_Fabia_1.4_TDI_PD_Classic   3600    small car                2008
# 6      Peugeot_206_CC_110_Platinum   2200  convertible                2004
# 9                Mazda_3_1.6_Sport   2000      unknown                2004
# 12  VW_PASSAT_1.9_TDI_131_PS_LEDER   2500        combi                2004
#
#      gearbox  powerCV  kilometer fuelType       brand
# 3   manually     74.0     150000   petrol  volkswagen
# 4   manually     68.0      90000   diesel       skoda
# 6   manually    108.0     150000   petrol     peugeot
# 9   manually    104.0     150000   petrol       mazda
# 12  manually    129.0     150000  unknown  volkswagen
# Informacion básica del dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258639 entries, 3 to 356304
# Data columns (total 9 columns):
# ...

# %% [markdown]
# Como tenemos pocos nulos en `powerCV`vamos a eliminarlos

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## EDA

# %%
eda(df)
# Out:
# Variables numéricas:
#
#  Index(['price', 'yearOfRegistration', 'powerCV', 'kilometer'], dtype='object')
#
# Variables categóricas:
#
#  Index(['name', 'vehicleType', 'gearbox', 'fuelType', 'brand'], dtype='object')
# Veamos las estadísticas básicas:
#                        count       mean       std     min       25%       50%  \
# price               244019.0    7297.43  12443.90   101.0    1899.0    4300.0
# yearOfRegistration  244019.0    2004.11      6.78  1951.0    2000.0    2004.0
# powerCV             244019.0     128.44     61.72    40.0      85.0     114.0
# kilometer           244019.0  122825.89  40375.59  5000.0  100000.0  150000.0
#
#                          75%        max
# price                 9250.0  1250000.0
# yearOfRegistration    2009.0     2018.0
# powerCV                158.0      549.0
# kilometer           150000.0   150000.0
#               count  unique         top    freq
# name         244019  143227    BMW_318i     567
# ...

# %%
matriz_correlacion(df)

# %% [markdown]
# ### Relaciones cruzadas

# %%
df.columns
# Out:
# Index(['name', 'price', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerCV', 'kilometer', 'fuelType', 'brand'],
#       dtype='object')

# %%
col_num = 'price'
col_cat = 'fuelType'
cols_num = df.select_dtypes(include='number').columns

for col in cols_num:
    if col == col_num:
        continue
    plt.figure(figsize=(7,5))
    sns.scatterplot(data=df[df['fuelType'].isin(['lpg','hybrid'])], x=col, y=col_num, hue=col_cat, alpha=0.3)
    plt.yscale('log')
    plt.show()

# %%
col_num = 'price'
cols_cat = df.select_dtypes(include=['category','O']).columns
for col in cols_cat:
    if col == 'name':
        continue
#Calcular el número de categorias unicas
    num_cats = df[col].nunique()

    #Ajustar dinamicamente el tamaño del grafico
    fig_width = max(4, num_cats *1.5)
    fig_height = 4

    cats_ordenadas = df.groupby(col)[col_num].mean().sort_values(ascending=False).index
    plt.figure(figsize=(fig_width, fig_height))
    sns.boxplot(x=df[col], y=df[col_num], hue= df[col], order=cats_ordenadas, palette='magma')
    plt.yscale('log')
    plt.show()

# %%
cols_cat
# Out:
# Index(['name', 'vehicleType', 'gearbox', 'fuelType', 'brand'], dtype='object')
